# %% [markdown]
# <a href="https://colab.research.google.com/github/shardeep-x/agentic-ai-and-gen-ai/blob/main/python_basic_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import time


A=np.random.rand(2000,2000)
B=np.random.rand(2000,2000)
print(A.size)

start=time.time()

C=np.matmul(A,B)
end=time.time()
print("CPU time: ", end-start)
# Out:
# 4000000
# CPU time:  0.35525941848754883

# %%
end=time.time()
print("CPU time: ", end-start)
# Out:
# CPU time:  80.53938913345337

# %%
import torch
import time


device="cuda"
A=torch.rand(2000,2000).to(device)
B=torch.rand(2000,2000).to(device)

start=time.time()
C=torch.matmul(A,B)
end=time.time()
print("GPU Time: ", end-start)
# Out:
# GPU Time:  0.12614774703979492

# %%
pip install python
# Out:
# ERROR: Could not find a version that satisfies the requirement python (from versions: none)
# ERROR: No matching distribution found for python

# %%
pip install numpy

# %%
PyPI

# %%
# !python -m venv ai_env
# Out:
# Error: Command '['/content/ai_env/bin/python3', '-m', 'ensurepip', '--upgrade', '--default-pip']' returned non-zero exit status 1.

# %%
[1,2,3]
# Out:
# [1, 2, 3]

# %%
[[1,2],
 [3,4]]
# Out:
# [[1, 2], [3, 4]]

# %%
import torch
x=torch.tensor([1,2,3])
print(x)
# Out:
# tensor([1, 2, 3])

# %%
import torch

a=torch.tensor([1,2,3])
b=torch.tensor([4,5,6])

c=a+b
print(c)
# Out:
# tensor([5, 7, 9])

# %%
import torch
x=torch.tensor(2.0, requires_grad=True)

y=x**2

y.backward()
print(x.grad)
# Out:
# tensor(4.)

# %%
pip install transformers torch

# %%
from transformers import pipeline

generator=pipeline(
    "text-generation",
    model="gpt2"
)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
prompt="Artificial Intelligence will transformer healthcare by"

# %%
result=generator(
    prompt,
    max_length=50,
    num_return_sequences=2
)
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)

# %%
print(result)
# Out:
# [{'generated_text': "Artificial Intelligence will transformer healthcare by providing better treatments and better access to health care for all.\n\nThe idea of AI and autonomous medical systems is revolutionary, yet it is still not totally clear how far we should go in this endeavor. The world needs our help. In this article, we outline the main challenges of AI, the challenges we need to overcome and the ways in which it can be harnessed.\n\nA computer program that can control itself is an amazing example of what we can do. The concept of a programmable robot is not new. The idea is that they can control themselves.\n\nThe human brain is just like any other computer. They communicate through sound waves, vibrations, electrical currents. They can perceive the world around them. They can read the contents of their surroundings. They can understand how to live and move around.\n\nWhen a computer's brain is designed, it is designed to be able to understand the world around it, understa
# ...

# %%
import torch

print(torch.cuda.is_available())
# Out:
# True

# %%
print(torch.version.cuda)
# Out:
# 12.8

# %%
print(torch.cuda.get_device_name(0))
# Out:
# Tesla T4
